# %% [markdown]
# # **BEMI Repository Setup Notebook**
# This notebook helps sets up the development environment. The configuration of this notebook for windows 10/11 systems only to for the sole completion for the requirements of CCS 249: Natural Language Processing as a Final Project.
#
# ---

# %% [markdown]
# ### **Step 1: Download Ollama**
# Download ollama by running the cell below or through their [website](https://ollama.com/download). You may skip this step, if ollama is already installed.

# %%
# !irm https://ollama.com/install.ps1 | iex

# %% [markdown]
# After downloading, run the cell below to check ollama health stats.

# %%
# !curl http://localhost:11434/api/tags

# %% [markdown]
# ### **Step 2: Pull Ollama Models**
# Pull required ollama models to be used. For the gemma4 model, the developer may choose between the 2b and 4b parameter model.

# %%
# !ollama pull embeddinggemma:latest

# %%
# !ollama pull gemma4:e2b
# !ollama pull gemma4:e4b

# %% [markdown]
# ### **Step 3: Create Virtual Python Environment**

# %%
# !python -m venv .venv

# %% [markdown]
# **IMPORTANT**: After successfuly creating the virtual environment, set your VSCode's kernel to `.venv (3.x.x)`.

# %% [markdown]
# ### **Step 4: Download Required Python Libraries**
# Run the cell below to install required libraries specified in `requirements.txt`.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ### **Step 5: Download Required Frontend Libraries**
# Run the cell below to install required libraries used in the frontend specified in `/interface/bun.lock`

# %%
# !cd interface && bun i

# %% [markdown]
# ---
# ## **Setup Complete!**
# Refer to `README.md` for the instructions to running the project.
