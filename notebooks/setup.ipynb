# %% [markdown]
# # **BEMI Repository Setup**
# ---

# %% [markdown]
# This notebook is designed to help set up the backend environment for the project repository. It includes instructions for installing necessary libraries and downloading required data

# %% [markdown]
# **Make sure to run each cell in order to ensure that all dependencies are properly installed and configured.**

# %% [markdown]
# ### **Step 1: Download Required Data**

# %% [markdown]
# Run the following code in a code cell to download the required NLTK data:

# %%
import nltk

DOWNLOAD_DIR = '../data/nltk'

nltk.download('punkt', download_dir=DOWNLOAD_DIR)
nltk.download('stopwords', download_dir=DOWNLOAD_DIR)
nltk.download('wordnet', download_dir=DOWNLOAD_DIR)
nltk.download('averaged_perceptron_tagger', download_dir=DOWNLOAD_DIR)

None

# %% [markdown]
# ### **Step 2: Download spaCy Model**

# %% [markdown]
# Run the following command in a code cell to download the spaCy model:

# %%
# !python -m spacy download en_core_web_sm --target ../models

# %% [markdown]
# **If no errors are raised, the backend setup is complete!**
